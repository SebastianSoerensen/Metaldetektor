# %%
import numpy as np
import sympy as sp
from scipy.constants import epsilon_0,mu_0,c
import matplotlib.pyplot as plt

# %%
## Operationsforstærker kredsløb
Vo = 5 ## Højest ønskede spænding på Arduino (porten kan kun tåle 5V)
Vin =   ## Højeste spænding fra spolen når den detekterer metal
Av=Vo/Vin
R1 = 10e3 ## 10k modstand som start gæt
R2sym = sp.symbols("R2sym",real=True)
eq1= sp.Eq(Av,1+R2sym/R1)
R2 = sp.solve(eq1,R2sym)[0]
sp.N(R2)
# Out:
# 4990000.00000000
