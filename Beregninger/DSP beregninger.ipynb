# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %%
N=64
def gen_hanning_values(N):
    M=N-1
    n = np.zeros(64)
    hanning=np.zeros(N)
    for n in range(N):
        hanning[i]=0.5-0.5*np.cos((2*np.pi*n)/(M))
        print(f"{hanning[i]:.3f}f,")
gen_hanning_values(N)
# Out:
# 0.000f,
# 0.002f,
# 0.010f,
# 0.022f,
# 0.039f,
# 0.061f,
# 0.087f,
# 0.117f,
# 0.151f,
# 0.188f,
# 0.229f,
# 0.272f,
# 0.317f,
# 0.365f,
# 0.413f,
# 0.463f,
# 0.512f,
# 0.562f,
# 0.611f,
# 0.659f,
# 0.706f,
# 0.750f,
# 0.792f,
# 0.831f,
# 0.867f,
# 0.899f,
# 0.927f,
# 0.950f,
# 0.970f,
# 0.985f,
# 0.994f,
# 0.999f,
# 0.999f,
# 0.994f,
# 0.985f,
# 0.970f,
# 0.950f,
# 0.927f,
# 0.899f,
# 0.867f,
# 0.831f,
# 0.792f,
# 0.750f,
# 0.706f,
# 0.659f,
# 0.611f,
# 0.562f,
# 0.512f,
# 0.463f,
# 0.413f,
# 0.365f,
# 0.317f,
# 0.272f,
# 0.229f,
# 0.188f,
# 0.151f,
# 0.117f,
# 0.087f,
# 0.061f,
# 0.039f,
# 0.022f,
# 0.010f,
# 0.002f,
# 0.000f,
